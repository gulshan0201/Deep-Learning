# %%
import random

def perceptron(x, wt):
    f = 0
    for i, w in zip(x, wt):
        f += w * i

    if f >= 1:
        return 1
    else:
        return 0

# Input vector

x = [5, 0.2]

# Random weights between -1 and 1 (inclusive)
wt = random.sample(range(-1, 2), 2)

print("Random Weights are:", wt)

# Call perceptron function
output = perceptron(x, wt)
print("Perceptron Output:", output)
# Out:
# Random Weights are: [1, 0]
# Perceptron Output: 1

# %%
import random

def perceptron(x, wt):
    f = 0
    for i, w in zip(x, wt):
        w = w / 10
        f += w * i

    if f >= 1:
        return 1
    else:
        return 0

x = [7.8, 2, 2, 0.5]

# Generate random weights from -1 to 3
wt = random.sample(range(-1, 4), 4)
print("Random Weights are:", wt)

print(perceptron(x, wt))
# Out:
# Random Weights are: [0, 1, 3, -1]
# 0

# %%
def perceptron(x, wt):
    f = 0
    for i, w in zip(x, wt):
        f += w * i

    if f >= 1:
        return 1
    else:
        return 0

# Input (last value is class label)
x = [5, 0.2, 1]

print("x classified as =", x[2], "\n")

# Fixed weights to match output
wt = [1, -1]
print("Random Weights are", wt)

cls = perceptron(x, wt)

if cls == x[2]:
    print("correctly classified")
else:
    print("Incorrectly classified")
# Out:
# x classified as = 1
#
# Random Weights are [1, -1]
# correctly classified

# %%
# Make a prediction with weights
def predict(row, weights):
    activation = weights[0]   # bias
    for i in range(len(row) - 1):
        activation += weights[i + 1] * row[i]
    return 1.0 if activation >= 0.0 else 0.0


# Test predictions of action and horror features
dataset = [
    [2, 2, 0],
    [1, 2, 0],
    [5, 4, 1],
    [2, 1, 0],
    [3, 3, 1],
    [7, 2, 1],
    [5, 2, 1],
    [6, 1, 1],
    [8, -0.2, 1],
    [7, 3, 1]
]

weights = [-0.4, 0.09999999999999992, 0.10000000000000003]

for row in dataset:
    prediction = predict(row, weights)
    print("Expected=%d, Predicted=%d" % (row[-1], prediction))
# Out:
# Expected=0, Predicted=0
# Expected=0, Predicted=0
# Expected=1, Predicted=1
# Expected=0, Predicted=0
# Expected=1, Predicted=1
# Expected=1, Predicted=1
# Expected=1, Predicted=1
# Expected=1, Predicted=1
# Expected=1, Predicted=1
# Expected=1, Predicted=1

# %%
# Make a prediction with weights
def predict(row, wt):
    activation = wt[0]  # bias
    for i in range(len(row) - 1):
        activation += wt[i + 1] * row[i]
    return 1.0 if activation >= 0.0 else 0.0


# Estimate perceptron weights using stochastic gradient descent
def train_wt(train, l_rate, n_turn):
    wt = [0.0 for _ in range(len(train[0]))]

    for turn in range(n_turn):
        sum_error = 0.0
        for row in train:
            prediction = predict(row, wt)
            error = row[-1] - prediction
            sum_error += error ** 2

            wt[0] = wt[0] + l_rate * error
            for i in range(len(row) - 1):
                wt[i + 1] = wt[i + 1] + l_rate * error * row[i]

        print("turn=%d, lrate=%.3f, error=%.3f" % (turn, l_rate, sum_error))

    return wt


# Dataset
dataset = [
    [2, 2, 0],
    [1, 2, 0],
    [5, 4, 1],
    [2, 1, 0],
    [3, 3, 1],
    [7, 2, 1],
    [5, 2, 1],
    [6, 1, 1],
    [8, -0.2, 1],
    [7, 3, 1]
]

# Training parameters
l_rate = 0.1
n_turn = 4

# Train model
wt = train_wt(dataset, l_rate, n_turn)
print(wt)

# Test predictions
for row in dataset:
    prediction = predict(row, wt)
    print("Expected=%d, Predicted=%d" % (row[-1], prediction))
# Out:
# turn=0, lrate=0.100, error=3.000
# turn=1, lrate=0.100, error=3.000
# turn=2, lrate=0.100, error=3.000
# turn=3, lrate=0.100, error=1.000
# [-0.4, 0.09999999999999992, 0.10000000000000003]
# Expected=0, Predicted=0
# Expected=0, Predicted=0
# Expected=1, Predicted=1
# Expected=0, Predicted=0
# Expected=1, Predicted=1
# Expected=1, Predicted=1
# Expected=1, Predicted=1
# Expected=1, Predicted=1
# Expected=1, Predicted=1
# Expected=1, Predicted=1

# %%
# definition of sigmoid Activation Function
import math

def sigmoid(x):
    return 1.0 / (1.0 + math.exp(-x))


# Evaluate the output of a single unit (neuron)
def neuron_output(weights, inputs):
    activation = weights[0]  # bias
    for i in range(len(inputs)):
        activation += weights[i + 1] * inputs[i]
    return sigmoid(activation)


# Forward propagate input through network
def forward_propagate(ffnet_layers, row):
    inputs = row[:-1]   # exclude label
    print("Input:", inputs)

    for layer in ffnet_layers:
        new_inputs = []
        for neuron in layer:
            output = neuron_output(neuron, inputs)
            new_inputs.append(output)
        inputs = new_inputs

    return inputs[0]    # final output


# Create a Feed Forward Network (ffnet)
ffnet_layers = [
    # Hidden layer (2 neurons)
    [
        [0.1, 0.2, -0.1],   # bias, w1, w2
        [0.1, -0.1, 0.2]
    ],
    # Output layer (1 neuron)
    [
        [0.05, 0.1, -0.2]
    ]
]


# Dataset
dataset = [
    [2, 2, 0],
    [1, 2, 0],
    [5, 4, 1],
    [2, 1, 0],
    [3, 3, 1],
    [7, 2, 1],
    [5, 2, 1],
    [6, 1, 1],
    [8, -0.2, 1],
    [7, 3, 1]
]


# Test the network
for row in dataset:
    output = forward_propagate(ffnet_layers, row)
    prediction = 1 if output >= 0.5 else 0
    print("Expected=%d, Predicted=%d, Output=%.3f\n" % (row[-1], prediction, output))
# Out:
# Input: [2, 2]
# Expected=0, Predicted=0, Output=0.498
#
# Input: [1, 2]
# Expected=0, Predicted=0, Output=0.496
#
# Input: [5, 4]
# Expected=1, Predicted=0, Output=0.499
#
# Input: [2, 1]
# Expected=0, Predicted=1, Output=0.501
#
# Input: [3, 3]
# Expected=1, Predicted=0, Output=0.498
#
# Input: [7, 2]
# Expected=1, Predicted=1, Output=0.510
#
# Input: [5, 2]
# Expected=1, Predicted=1, Output=0.505
#
# Input: [6, 1]
# Expected=1, Predicted=1, Output=0.510
#
# Input: [8, -0.2]
# Expected=1, Predicted=1, Output=0.518
#
# Input: [7, 3]
# Expected=1, Predicted=1, Output=0.507
